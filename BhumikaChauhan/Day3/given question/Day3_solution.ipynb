# %%
import numpy as np
arr = np.array([5,7,5,3,7])
x = np.unique(arr)
count = 0
for i in x:
  if(np.count_nonzero(arr == i) == 1):
    print("Unique element: ", i)
    count = 1
if count == 0:
  print("No unique element in array!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\91730\Downloads\Day3_solution.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91730/Downloads/Day3_solution.ipynb#ch0000000?line=0'>1</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/91730/Downloads/Day3_solution.ipynb#ch0000000?line=1'>2</a> arr = np.array([5,7,5,3,7])
#       <a href='vscode-notebook-cell:/c%3A/Users/91730/Downloads/Day3_solution.ipynb#ch0000000?line=2'>3</a> x = np.unique(arr)
#
# ModuleNotFoundError: No module named 'numpy'
